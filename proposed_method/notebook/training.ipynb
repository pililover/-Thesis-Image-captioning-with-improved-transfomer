# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q transformers accelerate torch_geometric Pillow peft sacrebleu
# !pip install -q accelerate torch_geometric Pillow peft sacrebleu
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 11.4 MB/s eta 0:00:00

# %%
# !pip uninstall -y torchao
# !pip uninstall transformers
# Out:
# Found existing installation: torchao 0.10.0
# Uninstalling torchao-0.10.0:
#   Successfully uninstalled torchao-0.10.0
# Found existing installation: transformers 5.10.2
# Uninstalling transformers-5.10.2:
#   Would remove:
#     /usr/local/bin/transformers
#     /usr/local/lib/python3.12/dist-packages/transformers-5.10.2.dist-info/*
#     /usr/local/lib/python3.12/dist-packages/transformers/*
# Proceed (Y/n)? y
#   Successfully uninstalled transformers-5.10.2

# %%
# !pip install transformers==4.51
# !pip install torchao --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 121.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 45.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 117.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.18.0
#     Uninstalling huggingface_hub-1.18.0:
#       Successfully uninstalled huggingface_hub-1.18.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 113.7 MB/s eta 0:00:00
# ...

# %%
import os
import sys

code_dir = "/content/drive/MyDrive/[Thesis] Improved_transformer/proposed_method"
os.chdir(code_dir)
sys.path.insert(0, code_dir)

print("CWD:", os.getcwd())
# Out:
# CWD: /content/drive/.shortcut-targets-by-id/1Oq2CScGIzBg7b2eNBCZtMOdpduaOAfoC/[Thesis] Improved_transformer/proposed_method

# %%
from huggingface_hub import login
login(token="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")

# %% [markdown]
# ## Full Dataset Training

# %%
import sys

for key in [k for k in sys.modules if k in ("train",) or k.startswith(("models.", "dataset", "collate"))]:
    del sys.modules[key]

from train import run_training
# Out:
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so

# %%
import argparse

DATA_DIR       = "/content/drive/MyDrive/[Thesis] Improved_transformer/data/proposed_method"
CHECKPOINT_DIR = "/content/drive/MyDrive/[Thesis] Improved_transformer/checkpoints"

args = argparse.Namespace(
    data_dir   = DATA_DIR,
    output_dir = CHECKPOINT_DIR,

    # Architecture
    mapping_network = "gatl",
    num_gat_layers  = 3,
    num_heads       = 8,
    use_gate        = True,
    use_fusion      = True,

    freeze_decoder = False,
    use_lora       = True,
    lora_r         = 16,
    lora_alpha     = 32,

    batch_size                  = 32,
    gradient_accumulation_steps = 2,
    epochs                      = 30,
    learning_rate               = 3e-5,
    warmup_steps                = 350,
    max_grad_norm               = 1.0,
    early_stopping_patience     = 5,
    eval_strategy               = "epoch",
    save_strategy               = "epoch",
    save_total_limit            = 1,

    dropout         = 0.1,
    label_smoothing = 0.1,
    weight_decay    = 0.01,

    bf16                   = True,
    dataloader_num_workers = 8,
    pin_memory             = True,
    clear_cache            = True,


    num_beams_eval     = 4,
    repetition_penalty = 1.1,

    lang = "en",

    logging_steps = 10,

    overfit_n  = None,
    resume     = None,

    push_to_hub = True,
    hf_repo_id  = "PuppetLover/scenegraph_image_captioning",
    hf_token    = "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",
)

trainer = run_training(args)
# Out:
# [Cache cleanup] Removing /root/.cache/huggingface/hub
#   ✓ Freed ~2-3GB
# config.json:   0%|          | 0.00/537 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.53G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/792 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/519 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/261 [00:00<?, ?B/s]
# Applying LoRA to mBART Decoder (r=16, alpha=32)
# trainable params: 8,650,752 || all params: 619,530,240 || trainable%: 1.3963
# model.safetensors:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/394 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/47.2k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/34.4M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# ...

# %%
import torch
torch.cuda.empty_cache()
